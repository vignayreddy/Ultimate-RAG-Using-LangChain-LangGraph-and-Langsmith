# %% [markdown]
# #### Chain Of Thoughts With RAG
# What is Chain-of-Thought (CoT) in RAG?
#
# CoT reasoning breaks down a complex question into intermediate steps, and allows retrieval + reflection at each step before answering.
#
# User Query
#    ↓
# - Step 1: Decompose question → sub-steps (Reason)
# - Step 2: Retrieve docs per step (Act)
# - Step 3: Combine context (Observe)
# - Step 4: Final answer generation (Reflect)

# %%
import os
from typing import List
from pydantic import BaseModel
from langchain_core.documents  import Document
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langgraph.graph import StateGraph, END

# %%
# -------------------------------
# 1. Prepare Vectorstore
# -------------------------------
docs = TextLoader("research_notes.txt",encoding="utf-8").load()
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(docs)
embedding = HuggingFaceEmbeddings()
vectorstore = FAISS.from_documents(chunks, embedding)
retriever = vectorstore.as_retriever()

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
llm = init_chat_model(
    "llama-3.3-70b-versatile",
    model_provider="groq"
)

# %%
# -------------------------------
# 2. LangGraph State Definition
# -------------------------------
class RAGCoTState(BaseModel):
    question: str
    sub_steps: List[str] = []
    retrieved_docs: List[Document] = []
    answer: str = ""

# %%
# -------------------------------
# 3. Nodes
# -------------------------------

# a. Plan sub-questions
def plan_steps(state:RAGCoTState):
    prompt = f"Break the question into 2-3 reasoning steps: \n\n {state.question}"
    result = llm.invoke(prompt).content
    subqs=[line.strip("-") for line in result.split("\n") if line.strip()]
    return state.model_copy(update={"sub_steps":subqs})

# %%
# b. Retrieve for each step
def retriever_per_step(state:RAGCoTState)->RAGCoTState:
    all_docs=[]
    for sub in state.sub_steps:
        docs = retriever.invoke(sub)
        all_docs.extend(docs)
    return state.model_copy(update={"retrieved_docs":all_docs})

# %%
# c. Generate Final Answer
def generate_answer(state: RAGCoTState) -> RAGCoTState:
    
    context = "\n\n".join([doc.page_content for doc in state.retrieved_docs])
    prompt = f"""
You are answering a complex question using reasoning and retrieved documents.

Question: {state.question}

Relevant Information:
{context}

Now synthesize a well-reasoned final answer.
"""
    result = llm.invoke(prompt).content.strip()
    return state.model_copy(update={"answer": result})

# %%
# -------------------------------
# 4. LangGraph Graph
# -------------------------------
builder = StateGraph(RAGCoTState)
builder.add_node("planner", plan_steps)
builder.add_node("retriever", retriever_per_step)
builder.add_node("responder", generate_answer)

builder.set_entry_point("planner")
builder.add_edge("planner", "retriever")
builder.add_edge("retriever", "responder")
builder.add_edge("responder", END)

graph = builder.compile()
graph

# %%
# -------------------------------
# 5. Run CoT RAG Agent
# -------------------------------
if __name__ == "__main__":
    query = "what are the additional eperiments in Transformer eveluation?"
    state = RAGCoTState(question=query)
    final = graph.invoke(state)

    print("\n🪜 Reasoning Steps:", final["sub_steps"])
    print("\n✅ Final Answer:\n", final["answer"])
# Out:
# 🪜 Reasoning Steps: ["To address the question of additional experiments in Transformer evaluation, let's break it down into reasoning steps:", "1. **Understanding the Basics of Transformer Evaluation**: The first step is to understand what the Transformer model is and how it's typically evaluated. The Transformer model, introduced by Vaswani et al. in 2017, is a deep learning model that relies entirely on self-attention mechanisms to process sequences of data, such as text. Common evaluation metrics for Transformers include perplexity for language modeling tasks, accuracy or F1-score for classification tasks, and BLEU score for translation tasks.", '2. **Identifying Standard Experiments**: The next step involves recognizing the standard experiments or evaluations that are commonly conducted on Transformer models. These can include training the model on a specific dataset (like WikiText for language modeling or IMDB for sentiment analysis), comparing it with other state-of-the-art models, and analyzing its performance under different hyperparameters (such as batch size, number of layers, or attention heads).', '3. **Exploring Additional Experiments for Comprehensive Evaluation**: ', "    - **Robustness and Adversarial Testing**: One set of additional experiments could involve testing the model's robustness to adversarial examples or out-of-distribution data to understand its reliability in real-world scenarios.", "    - **Cross-Lingual and Multitask Learning**: Another area could be evaluating the Transformer's ability to perform cross-lingually (i.e., training on one language and testing on another) or in multitask settings (i.e., training on multiple tasks simultaneously) to gauge its versatility and generalizability.", "    - **Efficiency and Scalability Experiments**: Experiments focusing on the model's computational efficiency, such as testing different pruning techniques, knowledge distillation, or sparse attention mechanisms, could provide insights into how to make Transformers more scalable and environmentally friendly.", "    - **Analyzing Attention Mechanisms**: Delving deeper into how the self-attention mechanisms work, perhaps by visualizing attention weights or manipulating them to understand their impact on specific tasks, could offer a more nuanced understanding of the model's decision-making process.", 'By following these reasoning steps, one can systematically approach the question of what additional experiments could be conducted to evaluate Transformers more comprehensively.']
#
# ✅ Final Answer:
#  The additional experiments in Transformer evaluation include:
#
# 1. **FlashAttention2**: Integrated into LLaMA2, which reduces context latency by ~50%.
# 2. **Chain-of-Thought prompting**: Outperforms direct answer prompting by 8% on logic tasks, and reflective prompting increases accuracy by 3%.
# 3. **Tool-augmented prompting**: Integrated LangGraph + Wikipedia + SQL search, enabling dynamic retrieval-agent reasoning.
# 4. **Human evaluation protocol**: Internal annotators score fluency, helpfulness, correctness, and GPT-4 is used as a synthetic evaluator.
# 5. **Retrieval experiments**: Hybrid dense + sparse retriever, testing Weaviate vs FAISS + BM25 reranking, with FAISS being more efficient but having slightly lower recall.
# 6. **LoRA tuning**: Used for adapter-based fine-tuning, reducing GPU memory footprint by 60% and compatible with the PEFT library.
# 7. **Safety**: Toxicity detection via Detoxify, out-of-scope filter via zero-shot classifier, and red teaming involved adversarial prompt testing.
#
# These experiments aim to improve the performance, efficiency, and safety of Transformer models, such as LLaMA2, and explore new techniques like tool-augmented prompting and retrieval experiments. The results of these experiments provide valuable insights into the capabilities and limitations of Transformer models and inform future research directions.
